# %% [markdown]
# # Types of Distribution Explained with Real-Life Examples

# %% [markdown]
# ## 📌 Objective
# To demonstrate types of distributions that are widely used in statistics with real life examples, explore the тature of the distributions and its features
