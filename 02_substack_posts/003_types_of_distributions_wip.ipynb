# %% [markdown]
# # Types of Distribution Explained with Real-Life Examples

# %% [markdown]
# ## 📑 Table of Contents
#
# 1. Objective
#
# 2. Basics of Probability Distributions
#    2.1 Discrete vs Continuous Distributions
#
# 3. Normal Distribution
#    3.1 Definition and Properties
#    3.2 Visualization with Python
#    3.3 Real-Life Example
#
# 4. Binomial Distribution
#    4.1 Definition and Properties
#    4.2 Visualization with Python
#    4.3 Real-Life Example
#
# 5. Poisson Distribution
#    5.1 Definition and Properties
#    5.2 Visualization with Python
#    5.3 Real-Life Example
#
# 6. Exponential Distribution
#    6.1 Definition and Properties
#    6.2 Visualization with Python
#    6.3 Real-Life Example
#
# 7. Uniform Distribution
#    7.1 Definition and Properties
#    7.2 Visualization with Python
#    7.3 Real-Life Example
#
# 8. Comparison of Distributions
#
# 9. Real Data / Simulation Example
#
# 10. Discussion
#
# 11. Conclusion
#
# 12. References

# %% [markdown]
# ## 📌 Objective
# This report dives into key probability distributions like normal, binomial, Poisson, exponential, and uniform to strengthen stats basics for data analysis and modeling.
#
# Main goals: explain properties of discrete (binomial, Poisson) and continuous (normal, exponential, uniform) types, show them with Python plots, and link to real examples

# %% [markdown]
# ## ☝️ Basics of Probability Distributions

# %% [markdown]
# **Basics of Probability Distributions**
# A probability distribution describes how the values of a random variable are spread out and how likely each value is. In simple terms, it tells you what outcomes are possible and how probable they are.
#
# Probability distributions are a core idea in statistics because they let you model uncertainty, summarize data, and make predictions. They are commonly described with a probability function, a table, or a graph.
#
# **Discrete vs Continuous Distributions**
#
# The main difference is the type of values the random variable can take. Discrete distributions apply to countable values, while continuous distributions apply to values across a range or interval.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# ── Discrete: Binomial distribution ───────────────────────────
n, p = 12, 0.5
k    = np.arange(0, n + 1)
pmf  = stats.binom.pmf(k, n, p)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

ax1.bar(k, pmf, color='#7F77DD', alpha=0.85, edgecolor='white')
ax1.set_title('Discrete PMF — Binomial(12, 0.4)')
ax1.set_xlabel('k (successes)')
ax1.set_ylabel('P(X = k)')

# ── Continuous: Normal distribution ───────────────────────────
x    = np.linspace(-5, 5, 300)
pdf  = stats.norm.pdf(x, loc=0, scale=1)
cdf  = stats.norm.cdf(x, loc=0, scale=1)

ax2.plot(x, pdf, color='#1D9E75', linewidth=2, label='PDF')
ax2.fill_between(x, pdf, alpha=0.15, color='#1D9E75')
ax2.plot(x, cdf, color='#0F6E56', linewidth=1.5, linestyle='--', label='CDF')
ax2.set_title('Continuous PDF — Normal(0, 1)')
ax2.set_xlabel('x')
ax2.legend()

plt.tight_layout()
plt.show()

# %% [raw]
# nornal explanation for people
# https://www.youtube.com/watch?v=lHCpYeFvTs0&t=187s

# %% [markdown]
# ## 🌊 Normal Distribution

# %% [markdown]
# really good explanation
# https://www.youtube.com/watch?v=3VYupIsbLlY

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

sns.set(style="whitegrid")

# %% [raw]
# https://www.youtube.com/watch?v=V3Qxj2C7rP0
